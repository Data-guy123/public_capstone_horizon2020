# %%
import pandas as pd
import requests
import time
import os

# --- Set file paths ---
pub_path = r"C:\Users\jawri\Data course\Capstone\CORDIS data\Projects\projectPublications.csv"
output_folder = r"C:\Users\jawri\Data course\Capstone\CORDIS data\Projects\alex"
os.makedirs(output_folder, exist_ok=True)

citations_path = os.path.join(output_folder, "project_citations.csv")
errors_path = os.path.join(output_folder, "citation_errors.csv")
email = "your email here"

# --- Load projectPublications.csv ---
publications = pd.read_csv(pub_path, sep=";", quoting=3, encoding="utf-8", on_bad_lines="skip")
publications.columns = publications.columns.str.strip().str.replace('"', '').str.lower()
publications['doi'] = publications['doi'].astype(str).str.strip().str.strip('"')

# --- Filter valid DOIs ---
valid_dois = publications['doi'].dropna().unique()
valid_dois = [d for d in valid_dois if d != '' and d != '0']

# --- Load existing citations if available ---
if os.path.exists(citations_path):
    existing = pd.read_csv(citations_path)
    already_done = set(existing['doi'].astype(str))
    print(f"✅ Loaded existing citations: {len(already_done)} DOIs already done.")
else:
    existing = pd.DataFrame(columns=['projectID', 'doi', 'cited_by_count'])
    already_done = set()
    print("ℹ️ No existing citation file found. Starting fresh.")

# --- Identify DOIs to process ---
new_dois = [doi for doi in valid_dois if doi not in already_done]
print(f"🔍 {len(new_dois)} new DOIs remaining.")

# --- Init containers ---
citation_data = []
failed_dois = []

# --- Start loop ---
for i, doi in enumerate(new_dois):
    url = f"https://api.openalex.org/works/doi:{doi}?mailto={email}"
    try:
        r = requests.get(url, timeout=10)
        if r.status_code == 200:
            cited_by = r.json().get("cited_by_count", None)
        else:
            cited_by = None
            failed_dois.append({'doi': doi, 'error': f"Status {r.status_code}"})
    except Exception as e:
        cited_by = None
        failed_dois.append({'doi': doi, 'error': str(e)})

    # Add all projectIDs using this DOI
    rows = publications[publications['doi'] == doi]
    for _, row in rows.iterrows():
        citation_data.append({
            "projectID": row['projectid'],
            "doi": doi,
            "cited_by_count": cited_by
        })

    # Save every 50
    if len(citation_data) % 50 == 0 or i == len(new_dois) - 1:
        temp_df = pd.DataFrame(citation_data)
        existing = pd.concat([existing, temp_df], ignore_index=True)
        existing.to_csv(citations_path, index=False)
        citation_data = []

        if failed_dois:
            err_df = pd.DataFrame(failed_dois)
            err_df.to_csv(errors_path, mode='a', index=False, header=not os.path.exists(errors_path))
            failed_dois = []

        print(f"💾 Saved progress at DOI {i+1} / {len(new_dois)}")

    time.sleep(0.1)

print("✅ Finished! All new citations saved.")
# Out:
# ℹ️ No existing citation file found. Starting fresh.
# 🔍 283149 new DOIs remaining.
# C:\Users\jawri\AppData\Local\Temp\ipykernel_10412\4070029260.py:68: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   existing = pd.concat([existing, temp_df], ignore_index=True)
# 💾 Saved progress at DOI 42 / 283149
# 💾 Saved progress at DOI 86 / 283149
# 💾 Saved progress at DOI 129 / 283149
# 💾 Saved progress at DOI 204 / 283149
# 💾 Saved progress at DOI 250 / 283149
# 💾 Saved progress at DOI 296 / 283149
# 💾 Saved progress at DOI 341 / 283149
# 💾 Saved progress at DOI 390 / 283149
# 💾 Saved progress at DOI 438 / 283149
# 💾 Saved progress at DOI 481 / 283149
# 💾 Saved progress at DOI 526 / 283149
# 💾 Saved progress at DOI 282326 / 283149
# 💾 Saved progress at DOI 282376 / 283149
# 💾 Saved progress at DOI 282426 / 283149
# 💾 Saved progress at DOI 282475 / 283149
# 💾 Saved progress at DOI 282525 / 283149
# 💾 Saved progress at DOI 282573 / 283149
# 💾 Saved progress at DOI 282622 / 283149
# 💾 Saved progress at DOI 282672 / 283149
# 💾 Saved progress at DOI 282722 / 283149
# 💾 Saved progress at DOI 282772 / 283149
# 💾 Saved progress at DOI 282822 / 283149
# 💾 Saved progress at DOI 282871 / 283149
# 💾 Saved progress at DOI 282921 / 283149
# 💾 Saved progress at DOI 282967 / 283149
# 💾 Saved progress at DOI 283016 / 283149
# 💾 Saved progress at DOI 283066 / 283149
# 💾 Saved progress at DOI 283116 / 283149
# 💾 Saved progress at DOI 283149 / 283149
# ✅ Finished! All new citations saved.

# %%
# Path to your citation file
citations_path = r"C:\Users\jawri\Data course\Capstone\CORDIS data\Projects\alex\project_citations.csv"

# Load it
citation_df = pd.read_csv(citations_path)

# Show first few rows
print("📄 Head of citation table:")
display(citation_df.head())

# Show summary stats
print("\n📊 Summary statistics:")
display(citation_df.describe())

# check data types and row count
print("\n🔎 Structure info:")
citation_df.info()
# Out:
# 📄 Head of citation table:
#   projectID                           doi  cited_by_count
# 0  "951475"  10.1016/j.eclinm.2022.101495            28.0
# 1  "825664"            10.1002/dad2.12242            28.0
# 2  "825664"  10.1001/jamaneurol.2021.3180           341.0
# 3  "825664"          10.1021/jacs.3c02022             7.0
# 4  "825546"     10.1016/j.mam.2024.101322             4.0
# 📊 Summary statistics:
#        cited_by_count
# count   205888.000000
# mean        41.489237
# std        150.800818
# min          0.000000
# 25%          4.000000
# 50%         15.000000
# 75%         38.000000
# max      19092.000000
# 🔎 Structure info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304433 entries, 0 to 304432
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   projectID       304433 non-null  object
#  1   doi             304420 non-null  object
#  2   cited_by_count  205888 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 7.0+ MB

# %%
errors_path = r"C:\Users\jawri\Data course\Capstone\CORDIS data\Projects\alex\citation_errors.csv"

# Load the failed DOI file
if os.path.exists(errors_path):
    errors_df = pd.read_csv(errors_path)
    print(f"❌ {len(errors_df)} failed DOIs found.")
    display(errors_df.head(10))  # Show first few
else:
    print("✅ No failed DOIs file found — all requests may have succeeded.")
# Out:
# ❌ 91003 failed DOIs found.
#                             doi       error
# 0     10.48550/arxiv.2503.05876  Status 404
# 1  10.1103/physrevd.107.035013}  Status 404
# 2          10.19283/lph2024.753  Status 404
# 3   10.33896/porient.2022.1–4.3  Status 404
# 4       10.25969/mediarep/19319  Status 404
# 5      10.13133/2532-6562/18849  Status 404
# 6         10.19272/202400601004  Status 404
# 7         10.69085/linc20251223  Status 404
# 8         10.52825/ocp.v5i.2342  Status 404
# 9         10.34813/ptr3.2022.10  Status 404

# %%
# Test a specific DOI manually
test_doi = "10.19283/lph2024.753"
url = f"https://api.openalex.org/works/doi:{test_doi}?mailto={email}"

r = requests.get(url, timeout=10)
print(f"Status code: {r.status_code}")

if r.status_code == 200:
    print("✅ OpenAlex returned data:")
    from pprint import pprint
    pprint(r.json())
else:
    print(f"❌ OpenAlex did not find the DOI. Response:")
    print(r.text)
# Out:
# Status code: 429
# ❌ OpenAlex did not find the DOI. Response:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <title>429 Too Many Requests</title>
# <h1>Too Many Requests</h1>
# <p>100000 per 1 day</p>

# %%
# Load the failed DOIs
errors_path = r"C:\Users\jawri\Data course\Capstone\CORDIS data\Projects\alex\citation_errors.csv"
errors_df = pd.read_csv(errors_path)

# Define common "bad" trailing characters
bad_chars = set('}])"\'')

# Function to check for trailing bad characters
def has_bad_trailing(doi):
    return doi and doi[-1] in bad_chars

# Apply function
errors_df['has_bad_trailing'] = errors_df['doi'].astype(str).apply(has_bad_trailing)

# Count how many
count_bad = errors_df['has_bad_trailing'].sum()
total = len(errors_df)

print(f"❗ DOIs with trailing bad characters: {count_bad} / {total}")

# Optional: show a few examples
print("\n🔍 Example bad DOIs:")
print(errors_df[errors_df['has_bad_trailing']]['doi'].head(10).to_list())
# Out:
# ❗ DOIs with trailing bad characters: 228 / 91003
#
# 🔍 Example bad DOIs:
# ['10.1103/physrevd.107.035013}', '10.3390/su15043008(registeringdoi)', '10.9770/jesi.2022.10.2(33)', '10.1007/978-981-13-0596-2_26++(springer.com)', '2020 21st IEEE International Conference on Mobile Data Management (MDM)', 'IEEE/CVF International Conference on Computer Vision (ICCV)', '17th Conference on Ph.D Research in Microelectronics and Electronics (PRIME)', '2022 IEEE International Symposium on Circuits and Systems (ISCAS)', '5th Planetary Data Workshop & Planetary Science Informatics & Analytics (Held virtually)', '7th IAA Planetary Defense Conference (held virtually)']

# %%
# Define characters you want to treat as bad at the end
bad_chars = set('}])"\'')

# Function to check for trailing junk
def has_bad_trailing(doi):
    try:
        return str(doi).strip()[-1] in bad_chars
    except:
        return False

# Apply safely
bad_trailing_flags = publications['doi'].apply(has_bad_trailing)

# Count how many DOIs in the original data had bad trailing characters
original_bad = bad_trailing_flags.sum()
print(f"❗ Original DOIs with bad trailing characters: {original_bad}")

# see examples
print("\n🔍 Examples:")
print(publications[bad_trailing_flags]['doi'].head(100).tolist())
# Out:
# ❗ Original DOIs with bad trailing characters: 262
#
# 🔍 Examples:
# ['10.1103/physrevd.107.035013}', '10.52152/22.4.150-209(2024)', '10.3390/su15043008(registeringdoi)', '10.9770/jesi.2017.4.3S(8)', '10.9770/jesi.2022.10.2(33)', '10.9770/jesi.2015.3.1(2)', '10.9770/jesi.2017.4.3S(3)', '10.9770/jesi.2018.6.1(17)', '10.9770/ird.2019.1.2(7)', '10.9770/ird.2019.1.3(6)', '10.9770/ird.2019.1.3(5)', '10.9770/ird.2019.1.3(4)', '10.9770/ird.2019.1.1(2)', '10.9770/jesi.2017.5.1(4)', '10.9770/ird.2019.1.3(1)', '10.9770/ird.2019.1.1(1)', '10.9770/jesi.2017.4.4(6)', '10.9770/jesi.2017.5.2(3)', '10.9770/jesi.2016.3.4(1)', '10.9770/jesi.2016.4.1(7)', '10.1130/2021.2550(29)', '10.1007/978-981-13-0596-2_26++(springer.com)', '2020 21st IEEE International Conference on Mobile Data Management (MDM)', 'IEEE/CVF International Conference on Computer Vision (ICCV)', '17th Conference on Ph.D Research in Microelectronics and Electronics (PRIME)', '2022 IEEE International Symposium on Circuits and Systems (ISCAS)', '5th Planetary Data Workshop & Planetary Science Informatics & Analytics (Held virtually)', '7th IAA Planetary Defense Conference (held virtually)', '14th International Conference on Applications of Statistics and Probability in Civil Engineering (ICASP14)', 'Kakoulin, M. (IMEC)', '2023 IEEE Conference on Virtual Reality and 3D User Interfaces Abstracts and Workshops (VRW)', '2022 International Conference on Robotics and Automation (ICRA)', '2021 IEEE 21st International Symposium on Computational Intelligence and Informatics (CINTI)', 'HORTA, Nuno (IT)', 'IEEE/RSJ International Conference on Intelligent Robots and Systems (IROS)', 'IMET - International Conference on Interactive Media, Smart Systems and Emerging Technologies (IMET)', 'Proceedings of  15th World Congress on Computational Mechanics (WCCM-XV) & the 8th Asian Pacific Congress on Computational Mechanics (APCOM-VIII)', '13th International Conference on Information, Intelligence, Systems & Applications (IISA)', 'arXiv (submitted to IEEE Transactions on Services Computing)', '69th International Astronautical Congress (IAC)', 'Association for Computing Machinery (ACM)', 'VIII International Symposium on Marine Sciences (2022)', '2022 Optical Fiber Communications Conference and Exhibition (OFC)', 'Proceedings of the 25th International Society of Magnetic Resonance in Medicine (ISMRM)', '39(7)', 'Proceedings of the 25th International Society of Magnetic Resonance in Medicine (ISMRM)', 'Recherche en Imagerie et Technologies pour la Santé (RITS)', '15th Greenhouse Gas control technology conference 15-18 March 2021 (GHGT-15)', '2021 IEEE MTT-S International Microwave Filter Workshop (IMFW)', 'Book of abstracts of The 11th International Congress on Membranes and Membrane Processes (ICOM 2017)', '2020 IEEE Photonics Conference (IPC)', 'Optical Networking and Communication Conference & Exhibition (OFC)', '21-25 (5)', '7617-7622 (6)', '2020 IEEE International Conference on Environment and Electrical Engineering and 2020 IEEE Industrial and Commercial Power Systems Europe (EEEIC / I&CPS Europe)', 'Kling, Rainer [Hrsg.]', '6th International Conference on Bio-Sensing Technology (BITE2019)', '2022 Optical Fiber Communications Conference and Exhibition (OFC)', 'JCGE 2017 (Jeunes Chercheurs en Génie Électrique)', 'Design Automation and Test in Europe Conference (DATE)', 'In Proceedings of the 2021 IFIP/IEEE International Symposium on Integrated Network Management (IM 2021)', '2023 IEEE Nuclear Science Symposium, Medical Imaging Conference and International Symposium on Room-Temperature Semiconductor Detectors (NSS MIC RTSD)', '2022 IEEE Transportation Electrification Conference & Expo (ITEC)', 'Green-IT Engineering: Social, Business and Industrial Applications (1−21)', '69th International Astronautical Congress (IAC)', '51st European Microwave Conference (EuMC)', '2021 IEEE 16th Conference on Industrial Electronics and Applications (ICIEA)', '2022 13th International Symposium on Communication Systems, Networks and Digital Signal Processing (CSNDSP)', '6th Internationa ...

# %%
# Ensure all DOIs are strings
publications['doi'] = publications['doi'].astype(str)

# Count DOIs that do NOT start with '10.'
invalid_count = (~publications['doi'].str.startswith("10.")).sum()

print(f"🚫 DOIs that do NOT start with '10.': {invalid_count}")
# Out:
# 🚫 DOIs that do NOT start with '10.': 96521

# %%
# Make sure 'doi' and 'projectid' are treated correctly
publications['doi'] = publications['doi'].astype(str).str.strip()
publications['projectid'] = publications['projectid'].astype(str).str.strip()

# Group by DOI and count number of unique projectIDs per DOI
projects_per_doi = publications.groupby('doi')['projectid'].nunique()

# Summary statistics
print("📊 Summary of project counts per DOI:")
print(projects_per_doi.describe())

# Most shared DOIs (top 10)
print("\n🔝 DOIs linked to the most different projects:")
print(projects_per_doi.sort_values(ascending=False).head(10))
# Out:
# 📊 Summary of project counts per DOI:
# count    283145.000000
# mean          1.108531
# std          24.225760
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max       12890.000000
# Name: projectid, dtype: float64
#
# 🔝 DOIs linked to the most different projects:
# doi
#                   12890
# 2022                 89
# 2021                 79
# 2020                 65
# 2018                 55
# 2023                 51
# 2019                 49
# 2017                 36
# 2016                 21
# 9781-510619524       16
# Name: projectid, dtype: int64

# %%
# Load the citation results
citations_path = r"C:\Users\jawri\Data course\Capstone\CORDIS data\Projects\alex\project_citations.csv"
citations = pd.read_csv(citations_path)

# Ensure DOI column is string
citations['doi'] = citations['doi'].astype(str)

# Check how many start with "10."
valid_count = citations['doi'].str.startswith("10.").sum()
total_count = len(citations)

print(f"✅ DOIs starting with '10.': {valid_count} / {total_count}")
print(f"📉 Proportion: {valid_count / total_count:.2%}")

# show a few that don't start with '10.'
print("\n🔍 Examples that do NOT start with '10.':")
print(citations[~citations['doi'].str.startswith("10.")]['doi'].dropna().unique()[:10])
# Out:
# ✅ DOIs starting with '10.': 295500 / 304433
# 📉 Proportion: 97.07%
#
# 🔍 Examples that do NOT start with '10.':
# ['20.500.11769/362880' '10230/46103' '101140/epjc/s10052-019-7140-6'
#  '10278/3701560' '0.1002/ett.3070' '107346/-fei-XIV-03-16_06'
#  'Krausmann, Fridolin' '1' '2' '217']

# %%
citations = pd.read_csv(citations_path)

dupes = citations.duplicated(subset=['projectID', 'doi']).sum()
print(f"🧾 Duplicate project–DOI pairs in citation file: {dupes}")
# Out:
# 🧾 Duplicate project–DOI pairs in citation file: 3442

# %%
# Load the original publication file
pub = pd.read_csv(pub_path, sep=";", quoting=3, encoding="utf-8", on_bad_lines="skip")
pub.columns = pub.columns.str.strip().str.replace('"', '').str.lower()
pub['doi'] = pub['doi'].astype(str).str.strip()

# Count unique project–DOI pairs in the source
pub_unique_pairs = pub.drop_duplicates(subset=['projectid', 'doi'])
print(f"📦 Unique project–DOI pairs in projectPublications.csv: {len(pub_unique_pairs)}")
# Out:
# 📦 Unique project–DOI pairs in projectPublications.csv: 313884

# %%
pub = pd.read_csv(pub_path, sep=";", quoting=3, encoding="utf-8", on_bad_lines="skip")
pub.columns = pub.columns.str.strip().str.replace('"', '').str.lower()
pub['doi'] = pub['doi'].astype(str).str.strip()

print(f"📄 Total rows in projectPublications.csv: {len(pub)}")
print(f"🧾 Unique project–DOI pairs: {pub.drop_duplicates(subset=['projectid', 'doi']).shape[0]}")
# Out:
# 📄 Total rows in projectPublications.csv: 392021
# 🧾 Unique project–DOI pairs: 313884

# %%
citations = pd.read_csv(citations_path)

# Clean up just in case
citations['doi'] = citations['doi'].astype(str).str.strip()

# Add length column
citations['doi_len'] = citations['doi'].str.len()

# Find shortest length and example(s)
min_len = citations['doi_len'].min()
shortest_dois = citations[citations['doi_len'] == min_len]['doi'].unique()

print(f"📏 Shortest DOI length: {min_len}")
print("🔍 Example(s):", shortest_dois[:5])
# Out:
# 📏 Shortest DOI length: 1
# 🔍 Example(s): ['1' '2' '9' '5' '3']

# %%
# Keep only rows where citation count was successfully retrieved
valid_citations = citations[citations['cited_by_count'].notna()]

print(f"✅ Valid citation rows: {len(valid_citations)} / {len(citations)}")
print(valid_citations.head())
# Out:
# ✅ Valid citation rows: 205888 / 304433
#   projectID                           doi  cited_by_count  doi_len
# 0  "951475"  10.1016/j.eclinm.2022.101495            28.0       28
# 1  "825664"            10.1002/dad2.12242            28.0       18
# 2  "825664"  10.1001/jamaneurol.2021.3180           341.0       28
# 3  "825664"          10.1021/jacs.3c02022             7.0       20
# 4  "825546"     10.1016/j.mam.2024.101322             4.0       25

# %%
# Test a specific DOI manually
test_doi = "10.1103/physrevd.107.035013"
url = f"https://api.openalex.org/works/doi:{test_doi}?mailto={email}"

r = requests.get(url, timeout=10)
print(f"Status code: {r.status_code}")

if r.status_code == 200:
    data = r.json()
    print("✅ OpenAlex returned data:")
    print(f"📊 Citation count: {data.get('cited_by_count', 'Not available')}")
else:
    print(f"❌ OpenAlex did not find the DOI. Response:")
    print(r.text)
# Out:
# Status code: 200
# ✅ OpenAlex returned data:
# 📊 Citation count: 1

# %%
# --- Load publications to map DOIs to projectIDs ---
publications = pd.read_csv(pub_path, sep=";", quoting=3, encoding="utf-8", on_bad_lines="skip")
publications.columns = publications.columns.str.strip().str.replace('"', '').str.lower()
publications['doi'] = publications['doi'].astype(str).str.strip().str.strip('"')

# --- Load citation_errors.csv ---
errors = pd.read_csv(errors_path)
errors['doi'] = errors['doi'].astype(str).str.strip().str.strip('"').str.strip('}])\'"+')

# Drop short or clearly junk DOIs
pre_filter_count = len(errors)
errors = errors[errors['doi'].str.len() > 5]
print(f"🧼 Dropped {pre_filter_count - len(errors)} DOIs with length <= 5")

# Ensure 'status' column exists
if 'status' not in errors.columns:
    errors['status'] = 'pending'

# Only retry ones not marked as success
errors_to_retry = errors[errors['status'] != 'success'].copy()
retry_dois = errors_to_retry['doi'].drop_duplicates().tolist()
print(f"📦 Total DOIs to retry after filtering: {len(retry_dois)}")

# --- Load existing citations ---
existing = pd.read_csv(citations_path)
already_done_pairs = set(zip(existing['projectID'].astype(str), existing['doi'].astype(str)))
print(f"✅ Loaded existing citations: {len(already_done_pairs)} project–DOI pairs already done.")

# --- Init containers ---
citation_data = []
failed_updates = []

# --- Retry loop ---
for i, doi in enumerate(retry_dois):
    url = f"https://api.openalex.org/works/doi:{doi}?mailto={email}"
    try:
        r = requests.get(url, timeout=10)
        status = r.status_code
        if status == 200:
            cited_by = r.json().get("cited_by_count", None)
        elif status == 429:
            print("🚫 RATE LIMIT REACHED: Too many requests — exiting loop.")
            break
        else:
            raise Exception(f"Status {status}")
    except Exception as e:
        errors.loc[errors['doi'] == doi, 'status'] = 'failed'
        if i % 10 == 0:
            print(f"❌ DOI {i+1}/{len(retry_dois)} failed: {doi} — {e}")
        continue

    # Lookup all projectIDs using this DOI
    rows = publications[publications['doi'] == doi]
    if rows.empty:
        errors.loc[errors['doi'] == doi, 'status'] = 'failed'
        if i % 10 == 0:
            print(f"⚠️ DOI {i+1}: {doi} returned data but matched 0 projectIDs")
        continue

    added_any = False
    for _, row in rows.iterrows():
        pair = (str(row['projectid']), doi)
        if pair not in already_done_pairs:
            citation_data.append({
                "projectID": row['projectid'],
                "doi": doi,
                "cited_by_count": cited_by
            })
            already_done_pairs.add(pair)
            added_any = True

    if added_any:
        errors.loc[errors['doi'] == doi, 'status'] = 'success'
    else:
        errors.loc[errors['doi'] == doi, 'status'] = 'failed'

    # Print status every 10
    if i % 10 == 0:
        print(f"🔁 {i+1}/{len(retry_dois)} — DOI: {doi} → Citations: {cited_by} | Projects linked: {len(rows)}")

    # Save every 50
    if len(citation_data) % 50 == 0 or i == len(retry_dois) - 1:
        if citation_data:
            temp_df = pd.DataFrame(citation_data)
            existing = pd.concat([existing, temp_df], ignore_index=True)
            existing.to_csv(citations_path, index=False)
            citation_data = []
            print(f"💾 Saved progress at DOI {i+1} / {len(retry_dois)}")

        errors.to_csv(errors_path, index=False)

    time.sleep(0.1)

print("✅ Retry loop complete.")
# Out:
# 🧼 Dropped 0 DOIs with length <= 5
# 📦 Total DOIs to retry after filtering: 4851
# ✅ Loaded existing citations: 300991 project–DOI pairs already done.
# ❌ DOI 1/4851 failed: 10.48550/arxiv.2503.05876 — Status 404
# ❌ DOI 11/4851 failed: 10.48550/arxiv.2504.01232 — Status 404
# ❌ DOI 21/4851 failed: 10.15199/42.2023.2.2 — Status 404
# ❌ DOI 31/4851 failed: 10.1049/stg2.12142ss — Status 404
# ❌ DOI 41/4851 failed: 10.19282/ac.32.1.2021.22 — Status 404
# ❌ DOI 51/4851 failed: 10.19229/2464-9309/11202022 — Status 404
# ❌ DOI 61/4851 failed: 10.57660/dpceonline.2023.1961 — Status 404
# ❌ DOI 71/4851 failed: 10.1073/pnas.210603111 — Status 404
# ❌ DOI 81/4851 failed: 10.5281/zenodo.10512965 — Status 404
# ❌ DOI 91/4851 failed: 10.1177/0170840623116200 — Status 404
# ❌ DOI 101/4851 failed: 10.1021/jacs.1c07497. — Status 404
# ❌ DOI 111/4851 failed: 10.5281/zenodo.4009797 — Status 404
# ❌ DOI 121/4851 failed: 10.1393/ncc/i2023-23145-3 — Status 404
# ❌ DOI 131/4851 failed: 10.1177/1079063223119008 — Status 404
# ❌ DOI 141/4851 failed: 10.6092/issn.2532-8816/18260 — Status 404
# ❌ DOI 151/4851 failed: 10.48550/arxiv.2402.15410 — Status 404
# ❌ DOI 161/4851 failed: 10.36253/aisthesis-14665 — Status 404
# ❌ DOI 171/4851 failed: 10.48550/arxiv.2304.06501 — Status 404
# ❌ DOI 181/4851 failed: 10.3389/fimmu.2022.930956.ecollection2022 — Status 404
# 🔁 931/4851 — DOI: 10.5194/bg-20-869-2023 → Citations: 12 | Projects linked: 3
# 🔁 941/4851 — DOI: 10.1126/sciadv.adj5569 → Citations: 8 | Projects linked: 1
# 🔁 951/4851 — DOI: 10.1016/j.expthermflusci.2019.109857 → Citations: 46 | Projects linked: 1
# 🔁 961/4851 — DOI: 10.1177/1475472x221107368 → Citations: 3 | Projects linked: 1
# 🔁 971/4851 — DOI: 10.1029/2018ef001064 → Citations: 27 | Projects linked: 1
# 🔁 981/4851 — DOI: 10.1016/j.jiec.2019.06.015 → Citations: 41 | Projects linked: 1
# 🔁 991/4851 — DOI: 10.1093/mnrasl/sly034 → Citations: 65 | Projects linked: 1
# 🔁 1001/4851 — DOI: 10.1080/07036337.2022.2074982 → Citations: 3 | Projects linked: 1
# 🔁 1011/4851 — DOI: 10.1111/evo.14383 → Citations: 14 | Projects linked: 1
# 🔁 1021/4851 — DOI: 10.1016/j.yhbeh.2021.105034 → Citations: 5 | Projects linked: 1
# 🔁 1031/4851 — DOI: 10.1098/rsbl.2020.0475 → Citations: 25 | Projects linked: 1
# 🔁 1041/4851 — DOI: 10.1098/rspb.2020.2104 → Citations: 21 | Projects linked: 1
# 🔁 1051/4851 — DOI: 10.1016/j.anbehav.2020.11.014 → Citations: 4 | Projects linked: 1
# 🔁 1061/4851 — DOI: 10.1126/scisignal.abp9521 → Citations: 7 | Projects linked: 1
# 🔁 1071/4851 — DOI: 10.1038/s41388-021-01803-8 → Citations: 23 | Projects linked: 1
# 🔁 1081/4851 — DOI: 10.1021/acsearthspacechem.9b00082 → Citations: 51 | Projects linked: 1
# 🔁 1091/4851 — DOI: 10.1093/mnras/sty2915 → Citations: 92 | Projects linked: 1
# 🔁 1101/4851 — DOI: 10.1051/0004-6361/201935127 → Citations: 15 | Projects linked: 1
# 🔁 1111/4851 — DOI: 10.3847/2041-8213/aad046 → Citations: 98 | Projects linked: 1
# 🔁 1121/4851 — DOI: 10.1109/tac.2019.2961998 → Citations: 24 | Projects linked: 1
# 🔁 1131/4851 — DOI: 10.1063/5.0004787 → Citations: 45 | Projects linked: 1
# 🔁 1141/4851 — DOI: 10.1109/tac.2019.2939191 → Citations: 20 | Projects linked: 1
# 🔁 1151/4851 — DOI: 10.1016/j.automatica.2019.05.059 → Citations: 100 | Projects linked: 1
# 🔁 1161/4851 — DOI: 10.1109/tac.2021.3064519 → Citations: 28 | Projects linked: 1
# 🔁 1171/4851 — DOI: 10.1080/21678421.2019.1606244 → Citations: 73 | Projects linked: 1
# 🔁 1181/4851 — DOI: 10.1038/s41467-017-00300-5 → Citations: 70 | Projects linked: 1
# 🔁 1191/4851 — DOI: 10.1007/s40812-020-00146-x → Citations: 0 | Projects linked: 1
# 🔁 1201/4851 — DOI: 10.1007/s10842-019-00329-w → Citations: 233 | Projects linked: 1
# 🔁 1211/4851 — DOI: 10.1093/icc/dtz059 → Citations: 12 | Projects linked: 1
# 🔁 1221/4851 — DOI: 10.1007/s10272-020-0891-3 → Citations: 59 | Projects linked: 1
# 🔁 1531/4851 — DOI: 10.3303/cet2080062 → Citations: 3 | Projects linked: 1
# 🔁 1541/4851 — DOI: 10.1364/oe.27.020231 → Citations: 38 | Projects linked: 1
# 🔁 1551/4851 — DOI: 10.1038/nnano.2016.261 → Citations: 196 | Projects linked: 1
# 🔁 1561/4851 — DOI: 10.1515/nanoph-2020-0609 → Citations: 20 | Projects linked: 1
# 🔁 1571/4851 — DOI: 10.1063/1.4977782 → Citations: 113 | Projects linked: 1
# 🔁 1581/4851 — DOI: 10.1103/physrevlett.122.067002 → Citations: 23 | Projects linked: 1
# 🔁 1591/4851 — DOI: 10.1016/j.enconman.2019.112423 → Citations: 26 | Projects linked: 1
# 🔁 1601/4851 — DOI: 10.1021/acsaelm.9b00329 → Citations: 15 | Projects linked: 1
# 🔁 1611/4851 — DOI: 10.1038/ncomms13406 → Citations: 125 | Projects linked: 1
# 🔁 1621/4851 — DOI: 10.1177/14687941221096594 → Citations: 22 | Projects linked: 1
# 🔁 1631/4851 — DOI: 10.1038/ncomms15720 → Citations: 88 | Projects linked: 1
# 🔁 1641/4851 — DOI: 10.18632/aging.101267 → Citations: 26 | Projects linked: 1
# 🔁 1651/4851 — DOI: 10.1109/LRA.2018.2818933 → Citations: 13 | Projects linked: 2
# 🔁 1661/4851 — DOI: 10.1051/0004-6361/201731950 → Citations: 14 | Projects linked: 1
# 🔁 1671/4851 — DOI: 10.3847/1538-4357/aa74d9 → Citations: 2 | Projects linked: 1
# 🔁 1681/4851 — DOI: 10.1021/acs.chemrev.7b00168 → Citations: 351 | Projects linked: 1
# 🔁 1691/4851 — DOI: 10.1038/s41598-017-04683-9 → Citations: 51 | Projects linked: 1
# 🔁 1701/4851 — DOI: 10.1103/PhysRevLett.118.266601 → Citations: 225 | Projects linked: 1
# 🔁 1711/4851 — DOI: 10.1016/j.scitotenv.2020.141162 → Citations: 31 | Projects linked: 1
# 🔁 1721/4851 — DOI: 10.3303/cet2080013 → Citations: 5 | Projects linked: 1
# 🔁 1731/4851 — DOI: 10.1016/j.egypro.2019.01.473 → Citations: 7 | Projects linked: 1
# 🔁 1741/4851 — DOI: 10.1016/j.renene.2022.10.025 → Citations: 17 | Projects linked: 1
# 🔁 1751/4851 — DOI: 10.1016/j.apenergy.2019.113904 → Citations: 101 | Projects linked: 1
# 🔁 1761/4851 — DOI: 10.1002/opph.201770306 → Citations: 2 | Projects linked: 1
# 🔁 1771/4851 — DOI: 10.1038/s41598-018-37867-y → Citations: 30 | Projects linked: 1
# 🔁 1781/4851 — DOI: 10.1051/0004-6361/201936547 → Citations: 23 | Projects linked: 1
# 🔁 1791/4851 — DOI: 10.3390/en13010053 → Citations: 46 | Projects linked: 1
# 🔁 1801/4851 — DOI: 10.1016/j.jaap.2020.104926 → Citations: 13 | Projects linked: 1
# 🔁 1811/4851 — DOI: 10.1209/0295-5075/ad2ff6 → Citations: 2 | Projects linked: 1
# 🔁 1821/4851 — DOI: 10.1103/prxenergy.1.033001 → Citations: 3 | Projects linked: 1
# 🔁 1831/4851 — DOI: 10.5194/essd-15-189-2023 → Citations: 8 | Projects linked: 1
# 🔁 1841/4851 — DOI: 10.1016/b978-0-323-88506-5.50109-1 → Citations: 0 | Projects linked: 2
# 🔁 1851/4851 — DOI: 10.1093/nar/gkac365 → Citations: 136 | Projects linked: 2
# 🔁 1861/4851 — DOI: 10.1016/j.agee.2023.108511 → Citations: 12 | Projects linked: 1
# 🔁 1871/4851 — DOI: 10.3390/biom12081014 → Citations: 5 | Projects linked: 1
# 🔁 1881/4851 — DOI: 10.1182/blood.2020007876 → Citations: 50 | Projects linked: 2
# 🔁 1891/4851 — DOI: 10.1103/physrevresearch.2.043340 → Citations: 5 | Projects linked: 2
# 🔁 1901/4851 — DOI: 10.1016/j.atmosenv.2019.116878 → Citations: 12 | Projects linked: 1
# 🔁 1911/4851 — DOI: 10.3389/fmedt.2024.1388207 → Citations: 2 | Projects linked: 1
# 🔁 1921/4851 — DOI: 10.1093/nar/gkad1200 → Citations: 12 | Projects linked: 1
# 🔁 1931/4851 — DOI: 10.1371/journal.pbio.3001935 → Citations: 11 | Projects linked: 1
# 🔁 1941/4851 — DOI: 10.1016/j.ijhydene.2023.03.439 → Citations: 8 | Projects linked: 1
# 🔁 1951/4851 — DOI: 10.1364/boe.488453 → Citations: 5 | Projects linked: 1
# 🔁 1961/4851 — DOI: 10.1364/ol.449720 → Citations: 8 | Projects linked: 1
# 🔁 1971/4851 — DOI: 10.1051/0004-6361/201834918 → Citations: 273 | Projects linked: 2
# 🔁 1981/4851 — DOI: 10.3847/1538-4357/ab765d → Citations: 7 | Projects linked: 1
# 🔁 1991/4851 — DOI: 10.1038/s41586-020-2932-2 → Citations: 179 | Projects linked: 1
# 🔁 2001/4851 — DOI: 10.1051/0004-6361/202039779 → Citations: 69 | Projects linked: 1
# 🔁 2011/4851 — DOI: 10.1093/bioinformatics/btac610 → Citations: 11 | Projects linked: 1
# 🔁 2021/4851 — DOI: 10.1371/journal.pcbi.1008798 → Citations: 10 | Projects linked: 1
# 🔁 2031/4851 — DOI: 10.2298/tsci220621110d → Citations: 1 | Projects linked: 1
# 🔁 2041/4851 — DOI: 10.1016/j.scitotenv.2021.148977 → Citations: 46 | Projects linked: 1
# 🔁 2051/4851 — DOI: 10.1051/0004-6361/202040218 → Citations: 47 | Projects linked: 2
# 🔁 2061/4851 — DOI: 10.1515/pjbr-2020-0036 → Citations: 38 | Projects linked: 2
# 🔁 2071/4851 — DOI: 10.1016/j.fuel.2020.119759 → Citations: 34 | Projects linked: 1
# 🔁 2081/4851 — DOI: 10.3324/haematol.2022.282596 → Citations: 6 | Projects linked: 1
# 🔁 2091/4851 — DOI: 10.1038/d41586-023-00521-3 → Citations: 0 | Projects linked: 1
# 🔁 2101/4851 — DOI: 10.3390/nano12152601 → Citations: 3 | Projects linked: 1
# 🔁 2111/4851 — DOI: 10.1021/acsnano.1c01220 → Citations: 74 | Projects linked: 1
# 🔁 2721/4851 — DOI: 10.3847/1538-4357/ac0d5a → Citations: 18 | Projects linked: 1
# 🔁 2731/4851 — DOI: 10.17771/pucrio.tradrev.45919 → Citations: 2 | Projects linked: 1
# 🔁 2741/4851 — DOI: 10.1093/mnras/stab2276 → Citations: 35 | Projects linked: 1
# 🔁 2751/4851 — DOI: 10.3389/falgy.2024.1297547 → Citations: 4 | Projects linked: 1
# 🔁 2761/4851 — DOI: 10.1242/jcs.260468 → Citations: 11 | Projects linked: 1
# 🔁 2771/4851 — DOI: 10.3390/land10121367 → Citations: 15 | Projects linked: 1
# 🔁 2781/4851 — DOI: 10.3390/jimaging7100214 → Citations: 18 | Projects linked: 1
# 🔁 2791/4851 — DOI: 10.1016/j.ijggc.2019.102792 → Citations: 19 | Projects linked: 1
# 🔁 2801/4851 — DOI: 10.1021/acs.energyfuels.0c00971 → Citations: 9 | Projects linked: 1
# 🔁 2811/4851 — DOI: 10.1016/j.nima.2022.167809 → Citations: 1 | Projects linked: 1
# 🔁 2821/4851 — DOI: 10.1029/2019rg000657 → Citations: 121 | Projects linked: 1
# 🔁 2831/4851 — DOI: 10.3390/toxins15110653 → Citations: 14 | Projects linked: 1
# 🔁 2841/4851 — DOI: 10.1007/jhep05(2018)094 → Citations: 15 | Projects linked: 1
# ❌ DOI 2851/4851 failed: 10.5283/epub.54802 — Status 404
# 🔁 2861/4851 — DOI: 10.1215/00265667-8623756 → Citations: 3 | Projects linked: 1
# 🔁 2871/4851 — DOI: 10.3389/fphys.2022.864547 → Citations: 11 | Projects linked: 1
# 🔁 2881/4851 — DOI: 10.3390/s22124335 → Citations: 17 | Projects linked: 1
# 🔁 2891/4851 — DOI: 10.1016/j.invent.2023.100657 → Citations: 2 | Projects linked: 1
# 🔁 2901/4851 — DOI: 10.3389/fenvs.2021.657969 → Citations: 53 | Projects linked: 1
# 🔁 2911/4851 — DOI: 10.5751/es-13509-270420 → Citations: 35 | Projects linked: 1
# 🔁 2921/4851 — DOI: 10.3390/su13084102 → Citations: 12 | Projects linked: 1
# 🔁 2931/4851 — DOI: 10.1093/ecco-jcc/jjaa252 → Citations: 48 | Projects linked: 1
# 🔁 2941/4851 — DOI: 10.1016/j.ufug.2023.128063 → Citations: 11 | Projects linked: 1
# 🔁 2951/4851 — DOI: 10.1016/j.tfp.2022.100252 → Citations: 40 | Projects linked: 1
# 🔁 2961/4851 — DOI: 10.3389/fmolb.2021.718301 → Citations: 19 | Projects linked: 1
# 🔁 2971/4851 — DOI: 10.33621/jdsr.v6i1.254 → Citations: 4 | Projects linked: 1
# 🔁 2981/4851 — DOI: 10.1017/err.2022.28 → Citations: 2 | Projects linked: 1
# 🔁 2991/4851 — DOI: 10.3389/fmed.2022.1019803 → Citations: 3 | Projects linked: 2
# 🔁 3001/4851 — DOI: 10.33182/joph.v2i2.1939 → Citations: 4 | Projects linked: 1
# 🔁 3011/4851 — DOI: 10.1038/s41467-020-15775-y → Citations: 54 | Projects linked: 1
# 🔁 3021/4851 — DOI: 10.1016/j.jpowsour.2024.234416 → Citations: 6 | Projects linked: 1
# 🔁 3031/4851 — DOI: 10.3390/land10010018 → Citations: 8 | Projects linked: 1
# 🔁 3041/4851 — DOI: 10.1007/jhep03(2019)133 → Citations: 33 | Projects linked: 1
# 🔁 3051/4851 — DOI: 10.5840/philtoday2021517406 → Citations: 10 | Projects linked: 1
# 🔁 3061/4851 — DOI: 10.1016/j.ijggc.2023.103990 → Citations: 1 | Projects linked: 1
# 🔁 3071/4851 — DOI: 10.7554/elife.76651 → Citations: 1 | Projects linked: 1
# 🔁 3081/4851 — DOI: 10.1016/j.envres.2023.115574 → Citations: 8 | Projects linked: 2
# 🔁 3091/4851 — DOI: 10.5751/es-13180-270217 → Citations: 40 | Projects linked: 1
# 🔁 3101/4851 — DOI: 10.1126/science.abq3616 → Citations: 276 | Projects linked: 1
# 🔁 3111/4851 — DOI: 10.1002/fes3.377 → Citations: 9 | Projects linked: 1
# 🔁 3121/4851 — DOI: 10.1007/s11856-023-2503-y → Citations: 2 | Projects linked: 1
# 🔁 3131/4851 — DOI: 10.1038/s41558-020-00967-7 → Citations: 83 | Projects linked: 1
# 🔁 3141/4851 — DOI: 10.1016/j.cma.2023.116552 → Citations: 9 | Projects linked: 1
# 🔁 3151/4851 — DOI: 10.1021/jacs.0c03760 → Citations: 43 | Projects linked: 1
# 🔁 3161/4851 — DOI: 10.5281/zenodo.6569441 → Citations: 0 | Projects linked: 1
# 🔁 3171/4851 — DOI: 10.1111/psyp.13598 → Citations: 13 | Projects linked: 1
# 🔁 3181/4851 — DOI: 10.3389/fmars.2023.1285793 → Citations: 6 | Projects linked: 1
# 🔁 3191/4851 — DOI: 10.1038/s41559-023-02037-5 → Citations: 25 | Projects linked: 1
# 🔁 3201/4851 — DOI: 10.1063/5.0069116 → Citations: 9 | Projects linked: 1
# 🔁 3211/4851 — DOI: 10.1175/jas-d-22-0028.1 → Citations: 19 | Projects linked: 1
# 🔁 3221/4851 — DOI: 10.1002/anie.202404682 → Citations: 8 | Projects linked: 1
# 🔁 3231/4851 — DOI: 10.1002/adom.202202801 → Citations: 18 | Projects linked: 1
# ❌ DOI 3241/4851 failed: 10.17863/cam.91365 — Status 404
# 🔁 3251/4851 — DOI: 10.1016/j.ecolind.2021.107665 → Citations: 36 | Projects linked: 1
# 🔁 3261/4851 — DOI: 10.3390/f13020264 → Citations: 3 | Projects linked: 1
# 🔁 3271/4851 — DOI: 10.1177/19485506231218362 → Citations: 4 | Projects linked: 1
# 🔁 3281/4851 — DOI: 10.3758/s13423-019-01701-x → Citations: 86 | Projects linked: 1
# 🔁 3291/4851 — DOI: 10.23987/sts.126210 → Citations: 3 | Projects linked: 1
# 🔁 3301/4851 — DOI: 10.5194/isprs-annals-v-3-2022-361-2022 → Citations: 6 | Projects linked: 1
# 🔁 3311/4851 — DOI: 10.1083/jcb.201908078 → Citations: 39 | Projects linked: 1
# 🔁 3321/4851 — DOI: 10.1016/j.neuroimage.2020.117126 → Citations: 100 | Projects linked: 2
# 🔁 3331/4851 — DOI: 10.1080/01621459.2023.2260053 → Citations: 4 | Projects linked: 1
# 🔁 3341/4851 — DOI: 10.1016/j.algal.2023.103294 → Citations: 7 | Projects linked: 1
# 🔁 3351/4851 — DOI: 10.1016/j.slasd.2024.100166 → Citations: 2 | Projects linked: 1
# 🔁 3361/4851 — DOI: 10.1016/j.jmst.2020.02.036 → Citations: 18 | Projects linked: 1
# 🔁 3371/4851 — DOI: 10.1145/3637443 → Citations: 1 | Projects linked: 1
# 🔁 3381/4851 — DOI: 10.1016/j.eswa.2022.117866 → Citations: 9 | Projects linked: 1
# 🔁 3391/4851 — DOI: 10.1007/jhep07(2020)124 → Citations: 30 | Projects linked: 2
# 🔁 3401/4851 — DOI: 10.1016/j.aquaculture.2024.741015 → Citations: 4 | Projects linked: 1
# 🔁 3411/4851 — DOI: 10.3389/fmicb.2020.00442 → Citations: 461 | Projects linked: 1
# 🔁 3421/4851 — DOI: 10.1002/adma.202208354 → Citations: 34 | Projects linked: 1
# 🔁 3431/4851 — DOI: 10.3389/fmars.2022.1006010 → Citations: 4 | Projects linked: 1
# 🔁 3441/4851 — DOI: 10.1177/03043754231182476 → Citations: 2 | Projects linked: 1
# 🔁 3451/4851 — DOI: 10.1007/s00248-023-02278-8 → Citations: 7 | Projects linked: 1
# 🔁 3461/4851 — DOI: 10.1021/jacsau.2c00708 → Citations: 5 | Projects linked: 1
# 🔁 3471/4851 — DOI: 10.1016/j.simpa.2023.100578 → Citations: 3 | Projects linked: 1
# 🔁 3481/4851 — DOI: 10.1039/d1sc06931d → Citations: 49 | Projects linked: 1
# 🔁 3491/4851 — DOI: 10.1038/s41591-021-01586-1 → Citations: 33 | Projects linked: 1
# 🔁 3501/4851 — DOI: 10.1108/jchmsd-05-2022-0074 → Citations: 4 | Projects linked: 1
# 🔁 3511/4851 — DOI: 10.3390/app11072930 → Citations: 16 | Projects linked: 1
# 🔁 3521/4851 — DOI: 10.3390/fluids5030147 → Citations: 16 | Projects linked: 1
# 🔁 3531/4851 — DOI: 10.1002/app.54663 → Citations: 8 | Projects linked: 1
# 🔁 3541/4851 — DOI: 10.1088/1742-5468/ac4982 → Citations: 2 | Projects linked: 1
# 🔁 3551/4851 — DOI: 10.1017/s0017383520000212 → Citations: 14 | Projects linked: 1
# 🔁 3561/4851 — DOI: 10.1093/jrsssb/qkad010 → Citations: 7 | Projects linked: 1
# 🔁 3571/4851 — DOI: 10.1016/j.actamat.2019.11.021 → Citations: 25 | Projects linked: 1
# 🔁 3581/4851 — DOI: 10.1007/s41779-022-00801-7 → Citations: 4 | Projects linked: 1
# 🔁 3591/4851 — DOI: 10.1007/s00248-023-02338-z → Citations: 4 | Projects linked: 1
# 🔁 3601/4851 — DOI: 10.1016/j.cognition.2024.105757 → Citations: 1 | Projects linked: 1
# 🔁 3611/4851 — DOI: 10.1021/jacs.1c01931 → Citations: 86 | Projects linked: 1
# 🔁 3621/4851 — DOI: 10.1002/pssb.201800624 → Citations: 2 | Projects linked: 1
# 🔁 3631/4851 — DOI: 10.1093/jxb/erae183 → Citations: 9 | Projects linked: 1
# 🔁 3641/4851 — DOI: 10.1002/adma.202305784 → Citations: 27 | Projects linked: 1
# 🔁 3651/4851 — DOI: 10.1080/03932729.2023.2277212 → Citations: 1 | Projects linked: 1
# 🔁 3661/4851 — DOI: 10.1021/acs.chemmater.0c00483 → Citations: 80 | Projects linked: 1
# 🔁 3671/4851 — DOI: 10.1016/j.eti.2023.103316 → Citations: 6 | Projects linked: 1
# 🔁 3681/4851 — DOI: 10.1021/acs.joc.9b01872 → Citations: 24 | Projects linked: 1
# 🔁 3691/4851 — DOI: 10.1016/j.molcel.2022.12.005 → Citations: 35 | Projects linked: 1
# 🔁 3701/4851 — DOI: 10.1088/1748-9326/ac1a9c → Citations: 25 | Projects linked: 1
# 🔁 3711/4851 — DOI: 10.3389/fmars.2021.743105 → Citations: 16 | Projects linked: 2
# 🔁 3721/4851 — DOI: 10.1016/j.marpol.2022.105294 → Citations: 11 | Projects linked: 1
# 🔁 3731/4851 — DOI: 10.1007/978-3-031-43458-7_41 → Citations: 3 | Projects linked: 1
# 🔁 3741/4851 — DOI: 10.1002/ejoc.202301205 → Citations: 1 | Projects linked: 1
# 🔁 3751/4851 — DOI: 10.1002/cmdc.202100575 → Citations: 5 | Projects linked: 1
# 🔁 3761/4851 — DOI: 10.3390/cancers14051147 → Citations: 61 | Projects linked: 1
# 🔁 3771/4851 — DOI: 10.1016/j.jbc.2023.105013 → Citations: 6 | Projects linked: 1
# 🔁 3781/4851 — DOI: 10.1016/j.jaci.2019.04.008 → Citations: 8 | Projects linked: 1
# 🔁 3791/4851 — DOI: 10.3390/en16186677 → Citations: 2 | Projects linked: 1
# 🔁 3801/4851 — DOI: 10.3167/fcl.2019.850101 → Citations: 9 | Projects linked: 1
# 🔁 3811/4851 — DOI: 10.1002/aenm.202203859 → Citations: 26 | Projects linked: 1
# 🔁 3821/4851 — DOI: 10.1038/s42005-020-00494-z → Citations: 60 | Projects linked: 1
# 🔁 3831/4851 — DOI: 10.1111/jcpp.13979 → Citations: 0 | Projects linked: 1
# 🔁 3841/4851 — DOI: 10.1038/s41575-019-0134-x → Citations: 385 | Projects linked: 1
# 🔁 3851/4851 — DOI: 10.1088/1748-9326/ac72a3 → Citations: 5 | Projects linked: 1
# 🔁 3861/4851 — DOI: 10.46586/tches.v2021.i2.159-188 → Citations: 70 | Projects linked: 1
# 🔁 3871/4851 — DOI: 10.24033/asens.2539 → Citations: 54 | Projects linked: 1
# 🔁 3881/4851 — DOI: 10.1109/tnnls.2019.2934729 → Citations: 13 | Projects linked: 1
# 🔁 3891/4851 — DOI: 10.1016/j.envpol.2023.123159 → Citations: 11 | Projects linked: 1
# 🔁 3901/4851 — DOI: 10.1111/dme.15259 → Citations: 10 | Projects linked: 1
# 🔁 3911/4851 — DOI: 10.1016/j.ress.2018.07.021 → Citations: 169 | Projects linked: 1
# 🔁 3921/4851 — DOI: 10.1016/j.neuron.2019.09.043 → Citations: 87 | Projects linked: 1
# 🔁 3931/4851 — DOI: 10.1007/s00227-022-04171-3 → Citations: 6 | Projects linked: 1
# 🔁 3941/4851 — DOI: 10.1007/s43154-020-00041-2 → Citations: 7 | Projects linked: 1
# 🔁 3951/4851 — DOI: 10.1016/j.cmpbup.2023.100101 → Citations: 5 | Projects linked: 1
# 🔁 3961/4851 — DOI: 10.3389/fchem.2020.00026 → Citations: 8 | Projects linked: 1
# 🔁 3971/4851 — DOI: 10.1007/s10845-021-01796-x → Citations: 111 | Projects linked: 1
# 🔁 3981/4851 — DOI: 10.3366/count.2022.0260 → Citations: 0 | Projects linked: 1
# 🔁 3991/4851 — DOI: 10.3389/fpubh.2023.1199664 → Citations: 7 | Projects linked: 1
# 🔁 4001/4851 — DOI: 10.3390/atmos11050535 → Citations: 25 | Projects linked: 1
# 🔁 4011/4851 — DOI: 10.1080/10509208.2019.1631692 → Citations: 7 | Projects linked: 1
# 🔁 4021/4851 — DOI: 10.1002/anie.202205725 → Citations: 74 | Projects linked: 1
# 🔁 4031/4851 — DOI: 10.1080/02673037.2024.2342411 → Citations: 3 | Projects linked: 1
# 🔁 4041/4851 — DOI: 10.46586/tches.v2023.i1.557-589 → Citations: 4 | Projects linked: 1
# 🔁 4051/4851 — DOI: 10.1103/physrevd.100.123543 → Citations: 52 | Projects linked: 1
# 🔁 4061/4851 — DOI: 10.1016/j.scitotenv.2022.159197 → Citations: 15 | Projects linked: 1
# 🔁 4071/4851 — DOI: 10.1016/j.sleh.2023.10.008 → Citations: 2 | Projects linked: 1
# 🔁 4081/4851 — DOI: 10.1001/jamapsychiatry.2023.4294 → Citations: 58 | Projects linked: 1
# 🔁 4091/4851 — DOI: 10.1016/j.foodchem.2024.138865 → Citations: 5 | Projects linked: 1
# 🔁 4101/4851 — DOI: 10.1038/s41534-020-00325-7 → Citations: 12 | Projects linked: 1
# 🔁 4111/4851 — DOI: 10.1332/204378921x16348942683000 → Citations: 4 | Projects linked: 1
# 🔁 4121/4851 — DOI: 10.1016/j.jhazmat.2021.127922 → Citations: 21 | Projects linked: 1
# 🔁 4131/4851 — DOI: 10.1038/s41467-022-35045-3 → Citations: 13 | Projects linked: 1
# 🔁 4141/4851 — DOI: 10.3303/cet2294136 → Citations: 3 | Projects linked: 1
# 🔁 4151/4851 — DOI: 10.1111/jac.12485 → Citations: 5 | Projects linked: 1
# 🔁 4161/4851 — DOI: 10.1016/j.jaci.2020.08.030 → Citations: 41 | Projects linked: 1
# 🔁 4171/4851 — DOI: 10.1016/j.jgo.2021.09.011 → Citations: 8 | Projects linked: 1
# 🔁 4181/4851 — DOI: 10.1016/j.rse.2023.113835 → Citations: 7 | Projects linked: 1
# 🔁 4191/4851 — DOI: 10.1038/s41596-022-00693-8 → Citations: 41 | Projects linked: 2
# 🔁 4201/4851 — DOI: 10.1016/j.jmr.2021.107083 → Citations: 6 | Projects linked: 1
# 🔁 4211/4851 — DOI: 10.3390/s21020653 → Citations: 8 | Projects linked: 1
# 🔁 4221/4851 — DOI: 10.1103/physrevd.107.046006 → Citations: 3 | Projects linked: 1
# 🔁 4231/4851 — DOI: 10.1103/physrevlett.129.113901 → Citations: 2 | Projects linked: 1
# 🔁 4241/4851 — DOI: 10.1007/s10579-023-09698-5 → Citations: 1 | Projects linked: 1
# 🔁 4251/4851 — DOI: 10.1016/j.jqsrt.2020.106932 → Citations: 32 | Projects linked: 1
# 🔁 4261/4851 — DOI: 10.1016/j.stem.2022.04.008 → Citations: 136 | Projects linked: 1
# 🔁 4271/4851 — DOI: 10.1088/1755-1315/774/1/012107 → Citations: 6 | Projects linked: 1
# 🔁 4281/4851 — DOI: 10.1016/j.euromechsol.2023.104947 → Citations: 17 | Projects linked: 1
# 🔁 4291/4851 — DOI: 10.1016/j.biortech.2023.129078 → Citations: 9 | Projects linked: 1
# 🔁 4301/4851 — DOI: 10.3390/membranes12030302 → Citations: 11 | Projects linked: 1
# 🔁 4311/4851 — DOI: 10.1115/1.4050671 → Citations: 14 | Projects linked: 1
# 🔁 4321/4851 — DOI: 10.1016/j.jobe.2023.107534 → Citations: 6 | Projects linked: 1
# 🔁 4331/4851 — DOI: 10.1016/j.heliyon.2020.e04135 → Citations: 46 | Projects linked: 1
# 🔁 4341/4851 — DOI: 10.3390/en16114492 → Citations: 5 | Projects linked: 1
# 🔁 4351/4851 — DOI: 10.1001/jamaophthalmol.2022.2113 → Citations: 12 | Projects linked: 1
# 🔁 4361/4851 — DOI: 10.1038/s41566-019-0435-1 → Citations: 348 | Projects linked: 2
# 🔁 4371/4851 — DOI: 10.1038/s41467-020-19108-x → Citations: 24 | Projects linked: 1
# 🔁 4381/4851 — DOI: 10.48550/arxiv.2208.04161 → Citations: 0 | Projects linked: 1
# 🔁 4391/4851 — DOI: 10.1177/10870547221129305 → Citations: 8 | Projects linked: 1
# ❌ DOI 4401/4851 failed: 10.48350/196803 — Status 404
# 🔁 4411/4851 — DOI: 10.3390/s23156914 → Citations: 3 | Projects linked: 1
# 🔁 4421/4851 — DOI: 10.1002/ecm.1522 → Citations: 14 | Projects linked: 1
# 🔁 4431/4851 — DOI: 10.4054/demres.2023.48.32 → Citations: 6 | Projects linked: 1
# 🔁 4441/4851 — DOI: 10.3390/ijms25031864 → Citations: 2 | Projects linked: 1
# 🔁 4451/4851 — DOI: 10.22452/ijie.vol15no4.5 → Citations: 1 | Projects linked: 1
# 🔁 4461/4851 — DOI: 10.3389/ti.2023.11705 → Citations: 4 | Projects linked: 1
# 🔁 4471/4851 — DOI: 10.1002/mbo3.1274 → Citations: 5 | Projects linked: 2
# 🔁 4481/4851 — DOI: 10.4204/eptcs.365.2 → Citations: 2 | Projects linked: 1
# 🔁 4491/4851 — DOI: 10.3390/biomedicines10123035 → Citations: 6 | Projects linked: 1
# 🔁 4501/4851 — DOI: 10.1038/s43587-022-00292-y → Citations: 62 | Projects linked: 1
# 🔁 4511/4851 — DOI: 10.3389/fcimb.2023.1166839 → Citations: 10 | Projects linked: 1
# 🔁 4521/4851 — DOI: 10.2478/johh-2022-0015 → Citations: 6 | Projects linked: 1
# 🔁 4531/4851 — DOI: 10.1021/acs.energyfuels.2c01345 → Citations: 9 | Projects linked: 1
# 🔁 4541/4851 — DOI: 10.3390/agriculture12071044 → Citations: 8 | Projects linked: 1
# 🔁 4551/4851 — DOI: 10.1371/journal.pone.0272344 → Citations: 2 | Projects linked: 1
# 🔁 4561/4851 — DOI: 10.1136/bmjopen-2020-047979 → Citations: 11 | Projects linked: 1
# 🔁 4571/4851 — DOI: 10.1186/s12913-022-08065-4 → Citations: 36 | Projects linked: 1
# 🔁 4581/4851 — DOI: 10.1111/spol.12871 → Citations: 5 | Projects linked: 1
# 🔁 4591/4851 — DOI: 10.1007/s13278-022-00915-7 → Citations: 7 | Projects linked: 1
# 🔁 4601/4851 — DOI: 10.1145/3577927 → Citations: 1 | Projects linked: 1
# 🔁 4611/4851 — DOI: 10.1002/aisy.202100150 → Citations: 25 | Projects linked: 1
# 🔁 4621/4851 — DOI: 10.1109/lra.2022.3154033 → Citations: 70 | Projects linked: 1
# 🔁 4631/4851 — DOI: 10.1088/1748-3190/ac98e6 → Citations: 11 | Projects linked: 1
# 🔁 4641/4851 — DOI: 10.3389/fimmu.2022.1006718 → Citations: 5 | Projects linked: 1
# 🔁 4651/4851 — DOI: 10.3390/ijms23179797 → Citations: 15 | Projects linked: 1
# 🔁 4661/4851 — DOI: 10.1016/j.dib.2021.107667 → Citations: 4 | Projects linked: 1
# 🔁 4671/4851 — DOI: 10.1136/bmjopen-2020-046544 → Citations: 0 | Projects linked: 1
# 🔁 4681/4851 — DOI: 10.3390/buildings12030264 → Citations: 15 | Projects linked: 1
# 🔁 4691/4851 — DOI: 10.12911/22998993/146270 → Citations: 4 | Projects linked: 1
# 🔁 4701/4851 — DOI: 10.1016/j.robot.2021.103970 → Citations: 19 | Projects linked: 1
# 🔁 4711/4851 — DOI: 10.1109/tsipn.2021.3067305 → Citations: 8 | Projects linked: 1
# 🔁 4721/4851 — DOI: 10.1021/acs.chemrev.1c00100 → Citations: 306 | Projects linked: 1
# 🔁 4731/4851 — DOI: 10.1093/hrlr/ngaa057 → Citations: 14 | Projects linked: 1
# 🔁 4741/4851 — DOI: 10.1016/j.procir.2020.12.001 → Citations: 17 | Projects linked: 1
# 🔁 4751/4851 — DOI: 10.1016/j.watres.2020.116423 → Citations: 87 | Projects linked: 1
# 🔁 4761/4851 — DOI: 10.1016/j.jss.2020.110812 → Citations: 25 | Projects linked: 2
# 🔁 4771/4851 — DOI: 10.1080/13683500.2021.1908967 → Citations: 59 | Projects linked: 1
# 🔁 4781/4851 — DOI: 10.1016/j.strueco.2020.05.007 → Citations: 26 | Projects linked: 1
# 🔁 4791/4851 — DOI: 10.1080/13501763.2020.1829005 → Citations: 33 | Projects linked: 1
# 🔁 4801/4851 — DOI: 10.1038/s41467-020-20155-7 → Citations: 98 | Projects linked: 2
# 🔁 4811/4851 — DOI: 10.1007/s10846-020-01250-9 → Citations: 65 | Projects linked: 1
# 🔁 4821/4851 — DOI: 10.1016/j.jclepro.2020.125604 → Citations: 57 | Projects linked: 1
# 🔁 4831/4851 — DOI: 10.1016/j.tpb.2019.07.012 → Citations: 17 | Projects linked: 1
# 🔁 4841/4851 — DOI: 10.1080/02699931.2020.1732875 → Citations: 21 | Projects linked: 1
# 🔁 4851/4851 — DOI: 10.1007/JHEP01(2020)093 → Citations: 1 | Projects linked: 1
# ✅ Retry loop complete.

# %%
# Load the updated citations file
citations_path = r"C:\Users\jawri\Data course\Capstone\CORDIS data\Projects\alex\project_citations.csv"
citations_df = pd.read_csv(citations_path)

print("📊 Total rows in citations (raw):", len(citations_df))
print("🔍 Unique DOIs:", citations_df['doi'].nunique())
print("🧮 Unique projectIDs:", citations_df['projectID'].nunique())

# 🧼 Drop duplicate (projectID, doi) pairs to avoid double counting
citations_df = citations_df.drop_duplicates(subset=['projectID', 'doi'])
print("✅ Rows after removing duplicates:", len(citations_df))

# Total citation count per projectID
project_citation_totals = citations_df.groupby('projectID')['cited_by_count'].sum().reset_index()
project_citation_totals = project_citation_totals.sort_values(by='cited_by_count', ascending=False)

# Show top 10
print("\n🏆 Top 10 projects by total citations:")
print(project_citation_totals.head(10))
# Out:
# 📊 Total rows in citations (raw): 304433
# 🔍 Unique DOIs: 283146
# 🧮 Unique projectIDs: 24984
# ✅ Rows after removing duplicates: 300991
#
# 🏆 Top 10 projects by total citations:
#       projectID  cited_by_count
# 4909   "633053"        135748.0
# 9755   "696656"        100070.0
# 9352   "692145"         80741.0
# 15445  "785219"         62017.0
# 5590   "641816"         45849.0
# 21463  "871029"         36820.0
# 7575   "665667"         34974.0
# 15484  "785907"         33018.0
# 6257   "647839"         29827.0
# 12724  "743080"         28238.0

# %%
citations_df[citations_df['projectID'] == '"633053"']['doi'].nunique()
# Out:
# 7332

# %%
citations_df[citations_df['projectID'] == '"633053"'].sort_values(by='cited_by_count', ascending=False).head(10)
# Out:
#       projectID                             doi  cited_by_count
# 50049  "633053"       10.1016/j.nds.2019.01.002           664.0
# 45764  "633053"          10.1126/sciadv.aav2002           515.0
# 49709  "633053"   10.1016/j.jnucmat.2018.10.027           486.0
# 46793  "633053"  10.1103/PhysRevLett.116.135504           440.0
# 50334  "633053"   10.1016/j.jnucmat.2020.152600           423.0
# 50098  "633053"    10.1103/revmodphys.88.015008           405.0
# 45315  "633053"   10.1016/j.jnucmat.2014.10.075           340.0
# 47084  "633053"          10.1098/rsta.2017.0432           319.0
# 47446  "633053"   10.1088/0029-5515/54/3/033007           306.0
# 51398  "633053"      10.1038/s41467-018-03415-5           305.0

# %%
# Count how many DOIs overlap between "633053" and other projects
dois_633053 = set(citations_df[citations_df['projectID'] == '"633053"']['doi'])
other_projects = citations_df[citations_df['projectID'] != '"633053"']
shared_dois = other_projects[other_projects['doi'].isin(dois_633053)]

# How many of those DOIs are shared?
print(f"Shared DOIs with other projects: {shared_dois['doi'].nunique()}")
# Out:
# Shared DOIs with other projects: 144

# %%
# Load the project data
proj_path = r"C:\Users\jawri\Data course\Capstone\CORDIS data\Projects\project.csv"
df = pd.read_csv(proj_path, sep=";", encoding="utf-8", quoting=3, on_bad_lines="skip")
df.columns = df.columns.str.strip().str.replace('"', '').str.lower()

# Force id column to string and strip extra spaces or quotes
df['id'] = df['id'].astype(str).str.strip().str.strip('"')

# Check what the first few IDs look like
print("🔍 Sample project IDs:")
print(df['id'].head(10).tolist())

# Try again to filter the row
target_id = '633053'
row = df[df['id'] == target_id]
print(f"\n📄 Project row for ID {target_id}:")
print(row)
# Out:
# 🔍 Sample project IDs:
# ['672641', '750248', '855867', '778157', '821431', '831756', '699794', '809304', '101003436', '846028']
#
# 📄 Project row for ID 633053:
# Empty DataFrame
# Columns: [id, acronym, status, title, startdate, enddate, totalcost, ecmaxcontribution, legalbasis, topics, ecsignaturedate, frameworkprogramme, mastercall, subcall, fundingscheme, nature, objective, contentupdatedate, rcn, grantdoi]
# Index: []

# %%
# Compare unique project IDs
unique_citation_ids = citations_df['projectID'].astype(str).str.strip().unique()
unique_project_ids = projects_df['id'].astype(str).str.strip().unique()

matched_ids = set(unique_citation_ids).intersection(set(unique_project_ids))
num_matched = len(matched_ids)
num_total = len(unique_citation_ids)
num_missing = num_total - num_matched

print(f"✅ Unique project IDs matched: {num_matched} / {num_total}")
print(f"❌ Unique project IDs missing from projects file: {num_missing}")
# Out:
# ✅ Unique project IDs matched: 16633 / 24980
# ❌ Unique project IDs missing from projects file: 8347

# %%
existing.shape
existing.head()
# Out:
#   projectID                           doi  cited_by_count
# 0  "951475"  10.1016/j.eclinm.2022.101495            28.0
# 1  "825664"            10.1002/dad2.12242            28.0
# 2  "825664"  10.1001/jamaneurol.2021.3180           341.0
# 3  "825664"          10.1021/jacs.3c02022             7.0
# 4  "825546"     10.1016/j.mam.2024.101322             4.0

# %%
len(existing)
# Out:
# 304433

# %%
existing.to_csv("recovered_project_citations.csv", index=False)

# %%
import csv
# Load the projects file
project_path = r"C:\Users\jawri\Data course\Capstone\CORDIS data\Projects\project.csv"
project_df = pd.read_csv(
    project_path,
    sep=';',
    quoting=csv.QUOTE_ALL,
    encoding='utf-8',
    on_bad_lines='skip'
)

# Load the recovered citations
citations = pd.read_csv("recovered_project_citations.csv")
# Remove quotes from projectID in citations
citations['projectID'] = citations['projectID'].str.strip('"')

# Convert projectID to string in both to ensure consistent comparison
project_df['projectID'] = project_df['id'].astype(str)
citations['projectID'] = citations['projectID'].astype(str)

# Compare projectIDs
print(f"Unique projectIDs in project_df: {project_df['id'].nunique()}")
print(f"Unique projectIDs in citations: {citations['projectID'].nunique()}")

# Check how many citation projectIDs match those in project_df
matched = citations['projectID'].isin(project_df['id'])
print(f"Matched projectIDs: {matched.sum()}")
print(f"Unmatched projectIDs: {(~matched).sum()}")
# Out:
# Unique projectIDs in project_df: 35105
# Unique projectIDs in citations: 24973
# Matched projectIDs: 0
# Unmatched projectIDs: 304433

# %%
print("Projects:", project_df['id'].astype(str).unique()[:5])
print("Citations:", citations['projectID'].unique()[:5])
# Out:
# Projects: ['672641' '750248' '855867' '778157' '798830']
# Citations: ['951475' '825664' '825546' '956454' '956439']

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\jawri
